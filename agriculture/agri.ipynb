# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
df=pd.DataFrame()
df=pd.read_csv('agri.csv', skiprows=0)
df
# Out:
#                                         ﻿Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          ADO
# 5                                              Angola          AGO
# 6                                 Antigua and Barbuda          ATG
# 7                                          Arab World          ARB
# 8                                           Argentina          ARG
# 9                                             Armenia          ARM
# 10                                              Aruba          ABW
# 11                                          Australia          AUS
# 12                                            Austria          AUT
# ...

# %%
df1 = df.dropna(thresh = 8)
df1 = df1.drop(['Country Code'], axis = 1, inplace = True, errors = 'ignore')
df1 = df1.drop(['Series Name'], axis = 1, inplace = True, errors = 'ignore')
df1 = df1.drop(['2014 [YR2014]'], axis = 1, inplace = True, errors = 'ignore')
df1 = df1.drop(['2015 [YR2015]'], axis = 1, inplace = True, errors = 'ignore')
fill_value = pd.DataFrame({col: df1.mean(axis=1) for col in df1.columns})
df1.fillna(fill_value, inplace=True)
df1['average'] = df1.mean(axis=1)
df1
# Out:
# /Users/haripadbharti/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-b8ecead7df5a> in <module>()
#       1 df1 = df.dropna(thresh = 8)
#       2 df1 = df1.drop(['Country Code'], axis = 1, inplace = True, errors = 'ignore')
# ----> 3 df1 = df1.drop(['Series Name'], axis = 1, inplace = True, errors = 'ignore')
#       4 df1 = df1.drop(['2014 [YR2014]'], axis = 1, inplace = True, errors = 'ignore')
#       5 df1 = df1.drop(['2015 [YR2015]'], axis = 1, inplace = True, errors = 'ignore')
#
# ...

# %%
df.drop(['Country Code'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['Series Name'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['2014 [YR2014]'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['2015 [YR2015]'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['Series Code'], axis = 1, inplace = True, errors = 'ignore')

# %%
df

# %%
df
df2=df
df2.drop(['Series Code'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['2014 [YR2014]'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['2015 [YR2015]'], axis = 1, inplace = True, errors = 'ignore')
df2.drop(['Country Name'], axis = 1, inplace = True, errors = 'ignore')

# %%
df1=df.ix[:,'2005 [YR2005]':'2013 [YR2013]']
df1
# Out:
#         2005 [YR2005]     2006 [YR2006]     2007 [YR2007]     2008 [YR2008]  \
# 0    58.0675795729559  58.0675795729559  58.0675795729559  58.0675795729559
# 1    39.3065693430657  40.8759124087591  40.8394160583942  43.1021897810219
# 2    17.3028962019364  17.2903003686381  17.3201105074441   17.344042590711
# 3                  25                25                24                24
# 4    41.9148936170213  41.4893617021277  41.2765957446808  41.9148936170213
# 5    46.1939520333681  46.1939520333681   46.274163792412   46.274163792412
# 6    20.4545454545455  20.4545454545455  20.4545454545455  20.4545454545455
# 7    40.0593416051623  40.0781795743962  40.1235005131786  40.0634942025868
# 8    50.3518849412977  51.5600963207378  52.6303673415696  52.7136796641198
# 9    56.3751317175975  61.6930101861609  61.5349490691956  61.3733754829645
# 10   11.1111111111111  11.1111111111111  11.1111111111111  11.1111111111111
# ...

# %%
fill_value = pd.DataFrame({col: df2.mean(axis=1) for col in df2.columns})
df2.fillna(fill_value, inplace=True)
df2['averag'] = df2.mean(axis=1)
df3 = df2.sort('averag', ascending=True)
# Out:
# /Users/haripadbharti/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
df=pd.DataFrame()
df=pd.read_csv('agri.csv', skiprows=0)
dm=pd.read_csv('agri.csv', skiprows=0)


df1=df.ix[:,'2005 [YR2005]':'2013 [YR2013]']
df3 = df2.sort('2013 [YR2013]', ascending=False)
df.drop(['2014 [YR2014]'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['2015 [YR2015]'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['Series Code'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['Country Code'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['Series Name'], axis = 1, inplace = True, errors = 'ignore')


new_cols = ['Country', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013']
df.columns = new_cols

df5 = df.dropna()
df5 = df5.sort('2013 [YR2013]', ascending=False)


df5
# Out:
# /Users/haripadbharti/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:11: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Users/haripadbharti/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/haripadbharti/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
df=pd.DataFrame()
df=pd.read_csv('agri.csv', skiprows=0)
dm=pd.read_csv('agri.csv', skiprows=0)


df1=df.ix[:,'2005 [YR2005]':'2013 [YR2013]']
df3 = df2.sort('2013 [YR2013]', ascending=False)
df.drop(['2014 [YR2014]'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['2015 [YR2015]'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['Series Code'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['Country Code'], axis = 1, inplace = True, errors = 'ignore')
df.drop(['Series Name'], axis = 1, inplace = True, errors = 'ignore')


new_cols = ['Country', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013']
df.columns = new_cols

df5 = df.dropna()
df5 = df5.sort('2013', ascending=False)
# Out:
# /Users/haripadbharti/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:11: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Users/haripadbharti/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
df5
# Out:
#                        Country               2005               2006  \
# 253                    Uruguay   84.7446006170723    83.961832933379
# 204               Saudi Arabia   80.8102563625453   80.7902534784085
# 119                 Kazakhstan   78.6331814646072    78.481497944216
# 137                      Libya   8.74376257430919   8.74376257430919
# 125                     Kuwait   8.41750841750842   8.41750841750842
# 95                      Guyana    8.5242570485141    8.5242570485141
# 39    Central African Republic   8.37105525056984   8.36302931073229
# 216               South Africa    80.359247871139   79.8687648896619
# 32                     Burundi   70.8333333333333   69.4314641744548
# 176                    Nigeria   79.8225677174259   80.4813509448049
# 66                 El Salvador    75.530888030888   71.1389961389961
# 234       Syrian Arab Republic   75.3282126709157   75.5704405598214
# 68                     Eritrea   74.4752475247525    74.970297029703
# ...

# %%
df5
# Out:
#                        Country               2005               2006  \
# 253                    Uruguay   84.7446006170723    83.961832933379
# 204               Saudi Arabia   80.8102563625453   80.7902534784085
# 119                 Kazakhstan   78.6331814646072    78.481497944216
# 137                      Libya   8.74376257430919   8.74376257430919
# 125                     Kuwait   8.41750841750842   8.41750841750842
# 95                      Guyana    8.5242570485141    8.5242570485141
# 39    Central African Republic   8.37105525056984   8.36302931073229
# 216               South Africa    80.359247871139   79.8687648896619
# 32                     Burundi   70.8333333333333   69.4314641744548
# 176                    Nigeria   79.8225677174259   80.4813509448049
# 66                 El Salvador    75.530888030888   71.1389961389961
# 234       Syrian Arab Republic   75.3282126709157   75.5704405598214
# 68                     Eritrea   74.4752475247525    74.970297029703
# ...

# %%
d1 = df5[df5['Country'].str.contains('income')]
d2 = df5[df5['Country'].str.contains('countries')]
d1.to_csv('d1.csv')
d2.to_csv('d2.csv')

# %%
df.to_csv('df.csv')

# %%
d11=d1.ix[:,'2008':'2013']
d11['Country'] = d1.ix[:,'Country']
d11
# Out:
# /Users/haripadbharti/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                  2008              2009              2010              2011  \
# 62   47.5809144891168  47.7355482327972  47.7966266562885  47.8718908724694
# 142  46.9303548870934  46.8394407762468  46.9191594491149  45.8099756721994
# 227  44.5935299552681   44.551565146208  44.7012383666938  43.7317858457841
# 141  38.5345376153545  38.6866347548521  38.8541933428143  39.0656427904018
# 140  38.2162735340388  38.2232117518945   38.367515359485  38.1628856954977
# 160  38.1638726884334  38.1469087472753  38.2873791639728  38.0142355492623
# ...

# %%
d11=d1.set_index(['Country'])
d11.plot(x=d1.index,kind='bar')
#ax.set_xticklabels(d11.index, rotation=180)
plt.xlabel('Country categories ')
plt.ylabel('Amount of carbon emission')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-242-c180e072c1cd> in <module>()
#       1
#       2 d11=d1.set_index(['Country'])
# ----> 3 d11.plot(x=d1.index,kind='bar')
#       4 #ax.set_xticklabels(d11.index, rotation=180)
#       5 plt.xlabel('Country categories ')
#
# /Users/haripadbharti/anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3738                           fontsize=fontsize, colormap=colormap, table=table,
#    3739                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3740                           sort_columns=sort_columns, **kwds)
# ...

# %%
dd = df5.head(20)
dd.to_csv('dd.csv')
